# %% [markdown]
# <a href="https://colab.research.google.com/github/hmyrcmn/mask-detection-yolo/blob/main/video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.0/757.0 kB 6.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/nvidia-curand-cu12/
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...

# %%
import cv2

video_path = '/content/input2.mp4'
cap = cv2.VideoCapture(video_path)

# %%
# %cd /content/result
# !yolo predict model=/content/best.pt source='/content/input2.mp4'
# Out:
# /content/result
# Ultralytics YOLOv8.2.17 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/440) /content/input2.mp4: 256x416 1 IncorrectMask, 96.0ms
# video 1/1 (frame 2/440) /content/input2.mp4: 256x416 1 IncorrectMask, 7.0ms
# video 1/1 (frame 3/440) /content/input2.mp4: 256x416 1 IncorrectMask, 6.3ms
# video 1/1 (frame 4/440) /content/input2.mp4: 256x416 1 IncorrectMask, 6.1ms
# video 1/1 (frame 5/440) /content/input2.mp4: 256x416 1 IncorrectMask, 7.1ms
# video 1/1 (frame 6/440) /content/input2.mp4: 256x416 1 IncorrectMask, 6.2ms
# video 1/1 (frame 7/440) /content/input2.mp4: 256x416 1 IncorrectMask, 6.2ms
# video 1/1 (frame 8/440) /content/input2.mp4: 256x416 2 IncorrectMasks, 6.4ms
# video 1/1 (frame 9/440) /content/input2.mp4: 256x416 1 IncorrectMask, 6.0ms
# video 1/1 (frame 10/440) /content/input2.mp4: 256x416 1 IncorrectMask, 6.8ms
# ...

# %%
# Gerekli kütüphaneyi yükleyin
# !apt-get install ffmpeg

# AVI dosyasını MP4 formatına dönüştürün
# !ffmpeg -i /content/result/runs/detect/predict/input2.avi int2-output.mp4
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
import cv2

video_path = '/content/input2.mp4'
cap = cv2.VideoCapture(video_path)
